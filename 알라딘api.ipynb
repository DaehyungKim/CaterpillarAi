# %%
import requests
import json

# %%
ALADIN_API_KEY = "ttbsk35021617001"
BASE_URL = "http://www.aladin.co.kr/ttb/api/ItemList.aspx"

params = {
    'ttbkey': ALADIN_API_KEY,
    'QueryType': 'ItemNewSpecial',
    'SearchTarget': 'book',
    'MaxResults': 10,

    'start': 1,
    'output': 'js',
    'Version': '20131101'
}

try:

    response = requests.get(BASE_URL, params=params)
    response.raise_for_status() # 오류 발생 시 예외 발생


    print(f"Status Code: {response.status_code}")


    data = response.json()
    print(json.dumps(data, indent=4, ensure_ascii=False))


    if 'item' in data:
        for book in data['item']:
            print(f"- {book.get('title')}")

except requests.exceptions.RequestException as e:
    print(f"API 요청 중 오류 발생: {e}")
except json.JSONDecodeError:
    print("JSON 응답 파싱 중 오류 발생")
    print(f"Raw response text: {response.text}")
# Out:
# Status Code: 200
# {
#     "version": "20131101",
#     "logo": "http://image.aladin.co.kr/img/header/2011/aladin_logo_new.gif",
#     "title": "알라딘 주목할 만한 신간 리스트 - 국내도서",
#     "link": "https://www.aladin.co.kr/shop/common/wnew.aspx?NewType=SpecialNew&amp;BranchType=1&amp;partner=openAPI",
#     "pubDate": "Fri, 25 Apr 2025 05:13:11 GMT",
#     "totalResults": 2253,
#     "startIndex": 1,
#     "itemsPerPage": 10,
#     "query": "QueryType=ITEMNEWSPECIAL;SearchTarget=book",
#     "searchCategoryId": 0,
#     "searchCategoryName": "국내도서",
#     "item": [
#         {
#             "title": "너였구나",
#             "link": "https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=363058812&amp;partner=openAPI&amp;start=api",
#             "author": "이석훈 (SG워너비) (지은이), 하수정 (그림)",
#             "pubDate": "2025-05-05",
#             "description": "가수, 뮤지컬 배우, MC, 라디오 DJ 등 다방면에서 활약하는 만능 아티스트 이석훈이 아들의 백일 선물로 발표한 자작곡 「너였구나」에 그림책 작가 하수정의 따뜻하고 포근한 그림이 더해져 완성된 그림책이다.",
#             "isbn": "K362038442",
#             "isbn13": "9791165703370",
#             "itemId": 363058812,
#             "priceSales": 15120,
#             "priceStandard": 16800,
#             "mallType": "BOOK",
#             "stockStatus": "",
#             "mileage": 840,
#             "cover": "https://image.aladin.co.kr/product/36305/88/coversum/k362038442_1.jpg",
#             "categoryId": 35134,
#             "categoryName": "국내도서>유아>그림책>나라별 그림책>한국 그림책",
#             "publisher": "창비교육",
#             "salesPoint": 0,
#             "adult": false,
#             "fixedPrice": true,
#             "customerReviewRank": 0,
#             "subInfo": {}
#         },
#         {
#             "title": "침묵하라 그리고 말하라",
#             "link": "https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=363058529&amp;partner=openAPI&amp;start=api",
#             "author": "법정 (지은이), 김인중 (그림)",
#             "pubDate": "2025-04-30",
#             "description": "부처님 오신 날을 맞아, 우리 시대 마지막 큰 어른으로 불렸던 법정 스님의 글을 엮은『침묵하라 그리고 말하라』가 출간됐다. 이 책은 세월을 뛰어넘어 여전히 깊은 울림을 전하는 법정 스님의 글 중 일부를 엄선해 담아낸 것으로, 말의 과잉과 소음 속에서 살아가는 현대인들에게 묵직한 메시지를 건넨다.",
#             "isbn": "K232038442",
#             "isbn13": "9791170403234",
#             "itemId": 363058529,
#             "priceSales": 17100,
#             "priceStandard": 19000,
#             "mallType": "BOOK",
#             "stockStatus": "",
#             "mileage": 950,
#             "cover": "https://image.aladin.co.kr/product/36305/85/coversum/k232038442_1.jpg",
#             "categoryId": 52906,
#             "categoryName": "국내도서>에세이>명사에세이>기타 명사에세이",
#             "publisher": "열림원",
#             "salesPoint": 0,
#             "adult": false,
#             "fixedPrice": true,
#             "customerReviewRank": 0,
#             "subInfo": {}
#         },
#         {
#             "title": "악어 급식 - 냠냠 쩝쩝",
#             "link": "https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=363057260&amp;partner=openAPI&amp;start=api",
#             "author": "주봄 (지은이), 김정진 (그림)",
#             "pubDate": "2025-05-15",
#             "description": "기상천외한 급식 메뉴를 통해 아이들의 마음을 돌보는 창작동화이다. 이 책에 나오는 김악어 선생님은 꿀꺽 초등학교 영양 교사로, 듣도 보도 못했을 만큼 독특한 음식을 만드는 것이 주특기이다. 그런데, 김악어 선생님이 특별히 준비한 음식에 비밀이 있다고?",
#             "isbn": "K932038442",
#             "isbn13": "9791162041901",
#             "itemId": 363057260,
#             "priceSales": 13050,
#             "priceStandard": 14500,
#             "mallType": "BOOK",
#             "stockStatus": "예약판매",
#             "mileage": 720,
#             "cover": "https://image.aladin.co.kr/product/36305/72/coversum/k932038442_1.jpg",
#             "categoryId": 48874,
#             "categoryName": "국내도서>어린이>동화/명작/고전>국내창작동화",
#             "publisher": "아르볼",
#             "salesPoint": 0,
#             "adult": false,
#             "fixedPrice": true,
#             "customerReviewRank": 0,
#             "subInfo": {}
#         },
#         {
#             "title": "퍄퍄킴 키워드 세계사",
#             "link": "https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=363057150&amp;partner=openAPI&amp;start=api",
#             "author": "샌드박스네트워크 (감수), 퍄퍄킴 역사 (기획), 박지영 (구성)",
#             "pubDate": "2025-05-01",
#             "description": "초중고 역사 수업 시간에도 활용되는 검증된 역사 유튜버, 퍄퍄킴 역사의 인기 콘텐츠가 재미있는 학습 만화로 출간되었다. 화장실, 전염병, 발명품, 다이어트, 판다, 해적 등의 흥미로운 키워드를 주제로, 궁금했지만 제대로 알 수 없었던 세계사 이야기가 담겨 있다.",
#             "isbn": "K982038442",
#             "isbn13": "9791166463365",
#             "itemId": 363057150,
#             "priceSales": 13500,
#             "priceStandard": 15000,
#             "mallType": "BOOK",
#             "stockStatus": "예약판매",
#             "mileage": 750,
#             "cover": "https://image.aladin.co.kr/product/36305/71/coversum/k982038442_1.jpg",
#             "categoryId": 48905,
#             "categoryName": "국내도서>어린이>사회/역사/철학>세계사",
#             "publisher": "기탄출판",
#             "salesPoint": 0,
#             "adult": false,
#             "fixedPrice": true,
#             "customerReviewRank": 0,
#             "subInfo": {}
#         },
#         {
#             "title": "어떤 모자를 쓸까? - 모자 속 세계 문화 이야기",
#             "link": "https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=363056079&amp;partner=openAPI&amp;start=api",
#             "author": "신현경 (지은이), 김현영 (그림)",
#             "pubDate": "2025-04-25",
#             "description": "",
#             "isbn": "K652038441",
#             "isbn13": "9791194636205",
#             "itemId": 363056079,
#             "priceSales": 13500,
#             "priceStandard": 15000,
#             "mallType": "BOOK",
#             "stockStatus": "",
#             "mileage": 750,
#             "cover": "https://image.aladin.co.kr/product/36305/60/coversum/k652038441_1.jpg",
#             "categoryId": 48900,
#             "categoryName": "국내도서>어린이>문화/예술/인물>세계문화",
#             "publisher": "풀빛",
#             "salesPoint": 0,
#             "adult": false,
#             "fixedPrice": true,
#             "customerReviewRank": 0,
#             "subInfo": {}
#         },
#         {
#             "title": "중독되는 아이들 - 미디어 세상에서 현명한 부모로 살기",
#             "link": "https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=363055970&amp;partner=openAPI&amp;start=api",
#             "author": "송지혜, 박소영, 김은주, 박성열, 김희연, 홍지선, 박민현, 이태엽 (지은이), 대한소아청소년정신의학회 (기획)",
#             "pubDate": "2025-05-01",
#             "description": "진료실에서의 상담 및 치료 경험과 뇌 연구를 기반으로 쓰인 이 책은 자녀들의 사례를 유형별, 문제별로 구체적으로 알려줘 실용성이 뛰어나다. 저자들이 특히 강조하는 것은 미디어 사용 규칙이다.",
#             "isbn": "K502038441",
#             "isbn13": "9791169093859",
#             "itemId": 363055970,
#             "priceSales": 15750,
#             "priceStandard": 17500,
#             "mallType": "BOOK",
#             "stockStatus": "",
#             "mileage": 870,
#             "cover": "https://image.aladin.co.kr/product/36305/59/coversum/k502038441_1.jpg",
#             "categoryId": 51786,
#             "categoryName": "국내도서>좋은부모>육아>육아법/육아 일반",
#             "publisher": "글항아리",
#             "salesPoint": 0,
#             "adult": false,
#             "fixedPrice": true,
#             "customerReviewRank": 0,
#             "seriesInfo": {
#                 "seriesId": 963201,
#                 "seriesLink": "http://www.aladin.co.kr/shop/common/wseriesitem.aspx?SRID=963201&amp;partner=openAPI",
#                 "seriesName": "속마음 시리즈 3"
#             },
#             "subInfo": {}
#         },
#         {
#             "title": "긴자 시호도 문구점 2",
#             "link": "https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=363050306&amp;partner=openAPI&amp;start=api",
#             "author": "우에다 겐지 (지은이), 최주연 (옮긴이)",
#             "pubDate": "2025-04-30",
#             "description": "",
#             "isbn": "K312038440",
#             "isbn13": "9791194654568",
#             "itemId": 363050306,
#             "priceSales": 15120,
#             "priceStandard": 16800,
#             "mallType": "BOOK",
#             "stockStatus": "",
#             "mileage": 840,
#             "cover": "https://image.aladin.co.kr/product/36305/3/coversum/k312038440_1.jpg",
#             "categoryId": 50998,
#             "categoryName": "국내도서>소설/시/희곡>일본소설>1950년대 이후 일본소설",
#             "publisher": "크래커",
#             "salesPoint": 0,
#             "adult": false,
#             "fixedPrice": true,
#             "customerReviewRank": 0,
#             "subInfo": {}
#         },
#         {
#             "title": "산딸기 아파트에 봄이 왔어요",
#             "link": "https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=363046777&amp;partner=openAPI&amp;start=api",
#             "author": "주미경 (지은이), 민승지 (그림)",
#             "pubDate": "2025-04-30",
#             "description": "여기저기 거닐기를 즐기는 주미경 작가가 글을 쓰고, 작업실로 비치는 햇살을 좋아하는 민승지 화가가 그림을 그린 『산딸기 아파트에 봄이 왔어요』는 찌뿌드드 뭉쳐 있던 마음이 풀어지는 봄날의 마법을 그린 이야기이다.",
#             "isbn": "K222038449",
#             "isbn13": "9791141602031",
#             "itemId": 363046777,
#             "priceSales": 13500,
#             "priceStandard": 15000,
#             "mallType": "BOOK",
#             "stockStatus": "",
#             "mileage": 750,
#             "cover": "https://image.aladin.co.kr/product/36304/67/coversum/k222038449_1.jpg",
#             "categoryId": 35134,
#             "categoryName": "국내도서>유아>그림책>나라별 그림책>한국 그림책",
#             "publisher": "문학동네",
#             "salesPoint": 0,
#             "adult": false,
#             "fixedPrice": true,
#             "customerReviewRank": 0,
#             "subInfo": {}
#         },
#         {
#             "title": "서울대 교수와 함께하는 10대를 위한 교양 수업 9 - 장구 교수님이 들려주는 수의학 이야기",
#             "link": "https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=363042947&amp;partner=openAPI&amp;start=api",
#             "author": "장구, 박여운 (지은이), 신병근 (그림)",
#             "pubDate": "2025-04-28",
#             "description": "",
#             "isbn": "K282038448",
#             "isbn13": "9791173571688",
#             "itemId": 363042947,
#             "priceSales": 13500,
#             "priceStandard": 15000,
#             "mallType": "BOOK",
#             "stockStatus": "",
#             "mileage": 750,
#             "cover": "https://image.aladin.co.kr/product/36304/29/coversum/k282038448_1.jpg",
#             "categoryId": 48848,
#             "categoryName": "국내도서>어린이>초등5~6학년>상식/교양",
#             "publisher": "아울북",
#             "salesPoint": 0,
#             "adult": false,
#             "fixedPrice": true,
#             "customerReviewRank": 0,
#             "seriesInfo": {
#                 "seriesId": 1095612,
#                 "seriesLink": "http://www.aladin.co.kr/shop/common/wseriesitem.aspx?SRID=1095612&amp;partner=openAPI",
#                 "seriesName": "서울대 교수와 함께하는 10대를 위한 교양 수업 9"
#             },
#             "subInfo": {}
#         },
#         {
#             "title": "원펀맨 One Punch Man 32 - 축복",
#             "link": "https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=363039652&amp;partner=openAPI&amp;start=api",
#             "author": "ONE (지은이), 무라타 유스케 (그림)",
#             "pubDate": "2025-04-28",
#             "description": "",
#             "isbn": "K412038347",
#             "isbn13": "9791142314025",
#             "itemId": 363039652,
#             "priceSales": 5400,
#             "priceStandard": 6000,
#             "mallType": "BOOK",
#             "stockStatus": "",
#             "mileage": 300,
#             "cover": "https://image.aladin.co.kr/product/36303/96/coversum/363039652_1.jpg",
#             "categoryId": 4133,
#             "categoryName": "국내도서>만화>본격장르만화>판타지>액션 판타지",
#             "publisher": "대원씨아이(만화)",
#             "salesPoint": 0,
#             "adult": false,
#             "fixedPrice": true,
#             "customerReviewRank": 0,
#             "subInfo": {}
#         }
#     ]
# }
# - 너였구나
# - 침묵하라 그리고 말하라
# - 악어 급식 - 냠냠 쩝쩝
# - 퍄퍄킴 키워드 세계사
# - 어떤 모자를 쓸까? - 모자 속 세계 문화 이야기
# - 중독되는 아이들 - 미디어 세상에서 현명한 부모로 살기
# - 긴자 시호도 문구점 2
# - 산딸기 아파트에 봄이 왔어요
# - 서울대 교수와 함께하는 10대를 위한 교양 수업 9 - 장구 교수님이 들려주는 수의학 이야기
# - 원펀맨 One Punch Man 32 - 축복

# %%
import requests
import json
import time
# 갯수 뽑아오기
ALADIN_API_KEY = "ttbsk35021617001"
BASE_URL = "http://www.aladin.co.kr/ttb/api/ItemList.aspx"

all_titles = []

for start in range(1, 51, 50):
    params = {
        'ttbkey': ALADIN_API_KEY,
        'QueryType': 'Bestseller',
        'SearchTarget': 'Book',
        'MaxResults': 50,
        'start': start,
        'output': 'js',
        'CategoryId': 2551,
        'Version': '20131101'
    }

    try:
        response = requests.get(BASE_URL, params=params)
        response.raise_for_status()

        data = response.json()
        items = data.get('item', [])

        for book in items:
            title = book.get('author')
            if title:
                all_titles.append(title)

        print(f"{start}번째부터 {start+49}번째까지 처리 완료.")

        time.sleep(1)

    except requests.exceptions.RequestException as e:
        print(f"요청 오류: {e}")
    except json.JSONDecodeError:
        print("JSON 파싱 오류")
        print(f"Raw response: {response.text}")


print(f"\n총 {len(all_titles)}권 수집 완료:\n")
for i, title in enumerate(all_titles, 1):
    print(f"{i}. {title}")
# Out:
# 1번째부터 50번째까지 처리 완료.
#
# 총 50권 수집 완료:
#
# 1. NAOE (지은이), 박소현 (옮긴이)
# 2. 호카조노 타케루 (지은이)
# 3. 아쿠타미 게게 (지은이), 이정운 (옮긴이)
# 4. 마츠모토 나오야 (원작), Kizuku Watanabe (그림), 유유리 (옮긴이)
# 5. 와야마 야마 (지은이), 현승희 (옮긴이)
# 6. 하마지 아키, 치바 사도루 (지은이)
# 7. 호카조노 타케루 (지은이)
# 8. 호시노 미즈키 (지은이), 김서은 (옮긴이)
# 9. 네오쇼코 (지은이), 김지혜 (옮긴이)
# 10. 하마지 아키, 치바 사도루 (지은이)
# 11. 노무라 유스케 (지은이), 카네시로 무네유키 (원작)
# 12. 산노미야 코타 (지은이), 카네시로 무네유키 (원작), 노무라 유스케 (그림)
# 13. 소라하나 미아 (지은이)
# 14. 스즈키 유우토 (지은이)
# 15. 후쿠다 신이치 (지은이), 박연지 (옮긴이)
# 16. 신조 케이고 (지은이), 장혜영 (옮긴이)
# 17. 모죠 (지은이)
# 18. 오오이시 나호 (지은이), 토리야마 아키라 (원작)
# 19. 모리시타 수 (지은이)
# 20. 시와스 유키 (지은이), 최윤정 (옮긴이)
# 21. 후지모토 타츠키 (지은이)
# 22. 찰리 맥커시 (지은이), 이진경 (옮긴이)
# 23. 아쿠타미 게게 (지은이), 이정운 (옮긴이)
# 24. 만리포 (지은이)
# 25. 오시로 고가니 (지은이), 김진희 (옮긴이)
# 26. 후쿠치 카미오 (지은이)
# 27. 와야마 야마 (지은이), 현승희 (옮긴이)
# 28. 아마미야 우리 (지은이)
# 29. 히다노 켄타로 (지은이), 마츠모토 나오야, Keiji Ando (원작), 유유리 (옮긴이)
# 30. 모쿠모쿠렌 (지은이), 송재희 (옮긴이)
# 31. 노무라 유스케 (지은이), 카네시로 무네유키 (원작)
# 32. 히노하라 메구루 (지은이)
# 33. 하마지 아키 (지은이)
# 34. CLAMP (지은이)
# 35. 후쿠다 신이치 (지은이), 박연지 (옮긴이)
# 36. 이가라시 마사쿠니 (지은이)
# 37. 타츠 유키노부 (지은이)
# 38. 아오야마 고쇼 (지은이)
# 39. 와야마 야마 (지은이), 현승희 (옮긴이)
# 40. 와야마 야마 (지은이), 현승희 (옮긴이)
# 41. 타치바나 오레코 (지은이), 유유리 (옮긴이)
# 42. 김차차 (원작), 청과 (그림), 초캄 (각색)
# 43. 김수정 (지은이)
# 44. 네오쇼코 (지은이), 김지혜 (옮긴이)
# 45. 호리코시 코헤이 (지은이), 오경화 (옮긴이)
# 46. NEXON GAMES (지은이), 김덕진 (옮긴이)
# 47. 오다 에이치로 (지은이)
# 48. 아이다이로 (지은이), 장혜영 (옮긴이)
# 49. 하마지 아키, 쿠미쵸 (지은이)
# 50. Tetsuo Ideuchi (지은이), Kuwahali (원작), 이소연 (옮긴이)

# %%
import re


def remove_parentheses(title):
    title = re.sub(r'\(.*?\)', '', title).strip()
    title = title.split(' - ')[0].strip()
    title = title.replace("'", "")
    title = re.sub(r'\s*초판본\s*', ' ', title).strip()
    return title

cleaned_titles = [remove_parentheses(title) for title in all_titles]
print(json.dumps(cleaned_titles, indent=4, ensure_ascii=False))
# Out:
# [
#     "NAOE , 박소현",
#     "호카조노 타케루",
#     "아쿠타미 게게 , 이정운",
#     "마츠모토 나오야 , Kizuku Watanabe , 유유리",
#     "와야마 야마 , 현승희",
#     "하마지 아키, 치바 사도루",
#     "호카조노 타케루",
#     "호시노 미즈키 , 김서은",
#     "네오쇼코 , 김지혜",
#     "하마지 아키, 치바 사도루",
#     "노무라 유스케 , 카네시로 무네유키",
#     "산노미야 코타 , 카네시로 무네유키 , 노무라 유스케",
#     "소라하나 미아",
#     "스즈키 유우토",
#     "후쿠다 신이치 , 박연지",
#     "신조 케이고 , 장혜영",
#     "모죠",
#     "오오이시 나호 , 토리야마 아키라",
#     "모리시타 수",
#     "시와스 유키 , 최윤정",
#     "후지모토 타츠키",
#     "찰리 맥커시 , 이진경",
#     "아쿠타미 게게 , 이정운",
#     "만리포",
#     "오시로 고가니 , 김진희",
#     "후쿠치 카미오",
#     "와야마 야마 , 현승희",
#     "아마미야 우리",
#     "히다노 켄타로 , 마츠모토 나오야, Keiji Ando , 유유리",
#     "모쿠모쿠렌 , 송재희",
#     "노무라 유스케 , 카네시로 무네유키",
#     "히노하라 메구루",
#     "하마지 아키",
#     "CLAMP",
#     "후쿠다 신이치 , 박연지",
#     "이가라시 마사쿠니",
#     "타츠 유키노부",
#     "아오야마 고쇼",
#     "와야마 야마 , 현승희",
#     "와야마 야마 , 현승희",
#     "타치바나 오레코 , 유유리",
#     "김차차 , 청과 , 초캄",
#     "김수정",
#     "네오쇼코 , 김지혜",
#     "호리코시 코헤이 , 오경화",
#     "NEXON GAMES , 김덕진",
#     "오다 에이치로",
#     "아이다이로 , 장혜영",
#     "하마지 아키, 쿠미쵸",
#     "Tetsuo Ideuchi , Kuwahali , 이소연"
# ]

# %%
# Out:
# [
#     "넥서스",
#     "세상은 라틴어로 가득하다",
#     "지리의 힘 3",
#     "새로 쓴 아틀라스 세계사",
#     "사피엔스",
#     "손자병법",
#     "총 균 쇠",
#     "거꾸로 읽는 세계사",
#     "황현필의 진보를 위한 역사",
#     "제국의 음모",
#     "무굴 제국의 역사",
#     "상식",
#     "거꾸로 읽는 한국사",
#     "분쟁 지역을 읽으면 세계가 보인다",
#     "사피엔스 : 그래픽 히스토리 Vol.1",
#     "바다의 황제",
#     "작은 사람들의 일상사",
#     "한국인의 탄생",
#     "무지의 역사",
#     "다시, 역사의 쓸모",
#     "역사의 시선",
#     "가요로 읽는 한국사",
#     "벌거벗은 세계사 : 과학편",
#     "망고와 수류탄",
#     "역사 문해력, 어떻게 가르칠까",
#     "100가지 식물로 읽는 세계사",
#     "중국공산당, 그 100년",
#     "나의 한국현대사 1959-2020",
#     "지리의 힘",
#     "물질의 세계",
#     "지리의 힘 2",
#     "야만의 해변에서",
#     "인텔리전스 랩",
#     "냉전",
#     "사피엔스 : 그래픽 히스토리 Vol.3",
#     "최소한의 한국사",
#     "사피엔스 : 그래픽 히스토리 Vol.2",
#     "중동태의 세계",
#     "욕망의 향신료 제국의 향신료",
#     "세계사를 바꾼 12가지 물질",
#     "역사의 쓸모",
#     "민족과 혁명",
#     "다시, 봄은 왔으나",
#     "꼬리에 꼬리를 무는 민주항쟁사",
#     "호떡과 초콜릿, 경성에 오다",
#     "민주공화국의 적은 누구인가",
#     "상하이를 떠나는 마지막 보트",
#     "버섯 중독",
#     "국화와 칼",
#     "지리로 다시 읽는 자본주의 세계사"
# ]
