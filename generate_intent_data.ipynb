# %%
import json
import random
import commentjson

my_label = 3
templatePath = 'intentTemplate/search_book_new_template.jsonc'
entityPath = 'entities/titlesWithjosa.jsonc'
authorPath = 'entities/authors.jsonc'

def choose_josa(word, josa_with_batchim, josa_without_batchim):
    if not word:
        return ""
    last_char = word[-1]

    if '가' <= last_char <= '힣':
        has_batchim = (ord(last_char) - ord('가')) % 28 > 0
        return josa_with_batchim if has_batchim else josa_without_batchim

    return josa_without_batchim

def process_korean_template(template, title, author):
    text = template.replace('{}', title)
    text = text.replace('[]', author)
    text = text.replace('{이}', choose_josa(title, '이', ''))
    text = text.replace('{은}', choose_josa(title, '은', '는'))
    text = text.replace('{를}', choose_josa(title, '을', '를'))
    text = text.replace('{과}', choose_josa(title, '과', '와'))
    text = text.replace('{가}', choose_josa(title, '이', '가'))
    text = text.replace('{으로}', choose_josa(title, '으로', '로'))

    return text

def generate_labeled_data(templates, entities, authors, label):
    output_data = []

    for template in templates:
        title = random.choice(entities)
        author = random.choice(authors)
        formatted_text = process_korean_template(template, title, author)
        data_point = {"text": formatted_text, "label": label}
        output_data.append(data_point)

    return output_data

# Load templates and entities
with open(templatePath, 'r', encoding='utf-8') as f:
    my_templates = commentjson.load(f)

with open(entityPath, 'r', encoding='utf-8') as f:
    my_entities = commentjson.load(f)

with open(authorPath, 'r', encoding='utf-8') as f:
    my_authors = commentjson.load(f)

# Generate labeled data
generated_data_set1 = generate_labeled_data(my_templates, my_entities, my_authors, my_label)

# Format output
item_strings = [json.dumps(item, ensure_ascii=False) for item in generated_data_set1]
output_string = "[\n" + ",\n".join(["  " + "{ " + s[1:-1] + " }" for s in item_strings]) + "\n]"
print(output_string)
# Out:
# [
#   { "text": "혹시 애나 로웬하웁트 칭 작가의 타잔 오브 디 에이프스 책이 몇 층에 있는지 알려주실 수 있나요?", "label": 2 },
#   { "text": "제가 찾는 조영민 작가의 경계의 저편 책이 이 도서관에 있나요? 어디에?", "label": 2 },
#   { "text": "어느 쪽으로 가야 프랜시스 스콧 피츠제럴드 작가의 보석의 나라 책을 찾을 수 있을지 모르겠어요.", "label": 2 },
#   { "text": "이 도서관에 프랜시스 스콧 피츠제럴드 작가의 쓰레기의 본망 책은 어디서 볼 수 있나요?", "label": 2 },
#   { "text": "다른 게 아니라, 콜리 황 작가의 쓰레기의 본망 책 서가 위치가 궁금해서요.", "label": 2 },
#   { "text": "여기서 말콤 글래드웰 작가의 나가토 유키짱의 소실 책을 찾으려면 어느 방향으로 가야해요?", "label": 2 },
#   { "text": "혹시 야우싱퉁, 스티브 네이디스 작가의 노트르담의 꼽추 책, 어디에 있는지 좀 찾아주실 수 있나요?", "label": 2 },
#   { "text": "제가 찾는 건 지미 송 작가의 아노하나 인데요, 위치 안내 좀 부탁드려요.", "label": 2 },
#   { "text": "어느 코너를 뒤져야 송용진 작가의 쓰레기의 본망 책이 나올까요?", "label": 2 },
#   { "text": "임인홍 작가가 쓴 신만이 아는 세계 책은 몇 층 서가에 있나요?", "label": 2 },
#   { "text": "크레이그 에번스 작가의 아사히나 미쿠루의 모험 책, 여기 있나요? 어디에 있어요?", "label": 2 },
#   { "text": "리 스트로벨 작가의 이세계 마왕과 소환 소녀의 노예 마술 책을 찾으려면 어디로 가야 하나요?", "label": 2 },
#   { "text": "신조 케이고 작가의 15소년 표류기 책은 어디에 비치되어 있나요?", "label": 2 },
#   { "text": "제인 오스틴 작가의 무채한의 팬텀 월드 책 서가는 어디인가요?", "label": 2 },
#   { "text": "크리스토퍼 라이트 작가의 죠죠의 기묘한 모험 책은 어느 구역에 있나요?", "label": 2 },
#   { "text": "레오르 즈미그로드 작가의 코이즈미 이츠키의 음모 책 위치를 확인해 주실 수 있을까요?", "label": 2 },
#   { "text": "올리버 색스 작가의 스즈미야 하루히의 분개 책 위치 좀 알려주세요.", "label": 2 },
#   { "text": "브라이언 콕스 작가의 성계의 문장 책은 보통 어느 코너에 있나요?", "label": 2 },
#   { "text": "김지훈 작가의 귀멸의 칼날 책은 몇 번 서가인가요?", "label": 2 },
#   { "text": "김용성 작가의 공전마도사 후보생의 교관 책을 대출하려면 어디로 가야 하나요?", "label": 2 },
#   { "text": "실례지만, 김기덕 작가의 오다 노부나의 야망 책 위치 좀 여쭤봐도 될까요?", "label": 2 },
#   { "text": "이 도서관 소장 도서 중에 Tetsuo Ideuchi 작가의 나의 행복한 결혼 책이 있다면 위치가 어디쯤 될까요?", "label": 2 },
#   { "text": "공자 작가의 스즈미야 하루히의 음모, 이 책 찾고 있는데 어디 있는지 아시나요?", "label": 2 },
#   { "text": "오오이시 나호 작가 우국의 모리아티 도서의 서가 위치를 안내받고 싶습니다.", "label": 2 },
#   { "text": "오시로 고가니 저자의 로빈슨 크루소의 모험 책은 어느 섹션에서 찾아볼 수 있나요?", "label": 2 },
#   { "text": "송용진 작가가 집필한 하늘의 유실물 책이 이 도서관에 있는지, 있다면 위치 좀 알려주세요.", "label": 2 },
#   { "text": "한강 작가의 4월은 너의 거짓말이라는 책을 검색하고 있는데, 서가 정보가 필요합니다.", "label": 2 },
#   { "text": "이 도서관에서 양성관 작가의 소공녀 세라 책을 열람하려면 어디로 가야합니까?", "label": 2 },
#   { "text": "제가 찾는 책은 캐시 윌리스 작가의 장 발장의 이야기 인데, 몇 층 어느 서가인지 알려주세요.", "label": 2 },
#   { "text": "혹시 허클베리 핀의 모험 책이 몇 층에 있는지 알려주실 수 있나요? 작가는 신조 케이고 입니다.", "label": 2 },
#   { "text": "제가 찾는 책은 단칸방의 침략자!?인데요, NEXON GAMES 작가 작품입니다. 이 도서관에 있나요? 있다면 어디에?", "label": 2 },
#   { "text": "아닐 아난타스와미 작가가 쓴 어떤 과학의 초전자포 책을 찾고 있는데, 어느 쪽으로 가야 할지 모르겠어요.", "label": 2 },
#   { "text": "이 도서관에서 전설의 용자의 전설 책, 그러니까 코이케 류노스케 작가가 쓴 책은 어디서 볼 수 있나요?", "label": 2 },
#   { "text": "다른 게 아니라, 성검사의 금주영창 책 서가 위치가 궁금해서요. 저자는 이성웅이고요.", "label": 2 },
#   { "text": "여기서 콜리 황 작가의 최애의 아이 책을 찾으려면 어느 방향으로 가야해요?", "label": 2 },
#   { "text": "혹시 북두의 권 책, 작가 조혜련 거 어디에 있는지 좀 찾아주실 수 있나요?", "label": 2 },
#   { "text": "제가 찾는 건 윌리엄 진서 작가가 쓴 재와 환상의 그림갈인데요, 위치 안내 좀 부탁드려요.", "label": 2 },
#   { "text": "허클베리 핀의 모험 책이요, 프란치스코 작가 건데 어느 코너를 뒤져야 나올까요?", "label": 2 },
#   { "text": "후쿠다 신이치 작가 책 중에 보석의 나라 이라는 제목의 책은 몇 층 서가에 있나요?", "label": 2 },
#   { "text": "성계의 전기 책 여기 있나요? 리처드 도킨스 작가 작품인데, 어디에 있어요?", "label": 2 },
#   { "text": "성각의 용기사 책을 찾으려면 어디로 가야 하나요? 저자는 프랜시스 스콧 피츠제럴드입니다.", "label": 2 },
#   { "text": "어니스트 헤밍웨이 작가의 저서 스즈미야 하루히의 음모 책은 어디에 비치되어 있나요?", "label": 2 },
#   { "text": "공전마도사 후보생의 교관 책의 서가는 어디인가요? 김수정 작가가 쓴 책입니다.", "label": 2 },
#   { "text": "무채한의 팬텀 월드 책은 어느 구역에 있나요? 작가는 시와스 유키로 알고 있습니다.", "label": 2 },
#   { "text": "사와 고지 작가가 집필한 어떤 마술의 금서목록 책의 위치를 확인해 주실 수 있을까요?", "label": 2 },
#   { "text": "아노하나 책 위치 좀 알려주세요. 신조 케이고 작가 겁니다.", "label": 2 },
#   { "text": "하얀 모래의 아쿠아토프 책은 보통 어느 코너에 있나요? 저자는 니콜로 마키아벨리 이고요.", "label": 2 },
#   { "text": "노무라 유스케 작가가 쓴 임금님 랭킹 책은 몇 번 서가인가요?", "label": 2 },
#   { "text": "프랑켄슈타인: 또는 현대의 프로메테우스 책을 대출하려면 어디로 가야 하나요? 작가는 영끌남 입니다.", "label": 2 },
#   { "text": "실례지만, 장송의 프리렌 책, 저자 안톤 파블로비치 체호프 의 작품 위치 좀 여쭤봐도 될까요?", "label": 2 },
#   { "text": "이 도서관 소장 도서 중에 롯테의 장난감! 책이 있다면 위치가 어디쯤 될까요? 참고로 아오야마 고쇼 작가 책입니다.", "label": 2 },
#   { "text": "네오쇼코, 이 작가가 쓴 귀멸의 칼날 책 찾고 있는데 어디 있는지 아시나요?", "label": 2 },
#   { "text": "학생회의 일존 도서의 서가 위치를 안내받고 싶습니다. 저자는 만리포입니다.", "label": 2 },
#   { "text": "가와시마 류타 저자의 세토의 신부 책은 어느 섹션에서 찾아볼 수 있는지 알려주세요.", "label": 2 },
#   { "text": "제가 스즈미야 하루히의 무료 책을 빌리고 싶은데, 호시노 미즈키 작가 책이 맞는지 확인하고 위치도 알려주세요.", "label": 2 },
#   { "text": "오오이시 나호 작가의 작품 중에서 소공자 세드릭 이 책의 서가 정보가 필요합니다.", "label": 2 },
#   { "text": "이 도서관에서 스즈미야 하루히의 직관 책을 열람하려면 어디로 가야 합니까? 저자는 앙투안 드 생텍쥐페리입니다.", "label": 2 },
#   { "text": "제가 찾는 책은 학생회의 일존이고, 작가는 정성진 인데, 몇 층 어느 서가인지 알려주세요.", "label": 2 }
# ]
