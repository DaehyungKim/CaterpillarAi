# %%
import json
import random
import commentjson

my_label = 0
templatePath = 'intentTemplate/search_book_new_template.jsonc'
entityPath = 'entities/titlesWithjosa.jsonc'
authorPath = 'entities/authors.jsonc'

def choose_josa(word, josa_with_batchim, josa_without_batchim):
    if not word:
        return ""
    last_char = word[-1]

    if '가' <= last_char <= '힣':
        has_batchim = (ord(last_char) - ord('가')) % 28 > 0
        return josa_with_batchim if has_batchim else josa_without_batchim

    return josa_without_batchim

def process_korean_template(template, title, author):
    text = template.replace('{}', title)
    text = text.replace('[]', author)
    text = text.replace('{이}', choose_josa(title, '이', ''))
    text = text.replace('{은}', choose_josa(title, '은', '는'))
    text = text.replace('{를}', choose_josa(title, '을', '를'))
    text = text.replace('{과}', choose_josa(title, '과', '와'))
    text = text.replace('{가}', choose_josa(title, '이', '가'))
    text = text.replace('{으로}', choose_josa(title, '으로', '로'))

    return text

def generate_labeled_data(templates, entities, authors, label):
    output_data = []

    for template in templates:
        title = random.choice(entities)
        author = random.choice(authors)
        formatted_text = process_korean_template(template, title, author)
        data_point = {"text": formatted_text, "label": label}
        output_data.append(data_point)

    return output_data

# Load templates and entities
with open(templatePath, 'r', encoding='utf-8') as f:
    my_templates = commentjson.load(f)

with open(entityPath, 'r', encoding='utf-8') as f:
    my_entities = commentjson.load(f)

with open(authorPath, 'r', encoding='utf-8') as f:
    my_authors = commentjson.load(f)

# Generate labeled data
generated_data_set1 = generate_labeled_data(my_templates, my_entities, my_authors, my_label)

# Format output
item_strings = [json.dumps(item, ensure_ascii=False) for item in generated_data_set1]
output_string = "[\n" + ",\n".join(["  " + "{ " + s[1:-1] + " }" for s in item_strings]) + "\n]"
print(output_string)
# Out:
# [
#   { "text": "전우성 작가의 스즈미야 하루히의 음모 책이 이 도서관에 있는지 검색해주실 수 있나요?", "label": 0 },
#   { "text": "혹시 알프스의 소녀 하이디 책, 지미 송 작가 거, 여기 소장 자료인지 확인 가능할까요?", "label": 0 },
#   { "text": "제가 찾는 책은 조성민 작가의 나츠메 우인장인데, 도서관 검색 시스템에서 찾아볼 수 있을까요?", "label": 0 },
#   { "text": "스즈미야 하루히의 우울 이 책, 오건영 작가 작품인데, 저희 도서관에 있는지 검색 부탁드립니다.", "label": 0 },
#   { "text": "브라이언 그린 작가가 쓴 마왕학원의 부적합자 책이 여기 있는지 조회 좀 해주세요.", "label": 0 },
#   { "text": "이 도서관 데이터베이스에서 신성관 작가의 히토리 봇치의 ○○생활 책을 검색해보고 싶습니다.", "label": 0 },
#   { "text": "바람의 검심 책, 저자가 호카조노 타케루인데, 소장 여부 확인 좀 부탁드릴게요.", "label": 0 },
#   { "text": "마르쿠스 아우렐리우스 작가의 작품 중에 스즈미야 하루히의 동요 이라는 책이 있는지 알아봐 주실 수 있나요?", "label": 0 },
#   { "text": "여기서 네빌 고다드 작가의 종말의 세라프 책을 검색하면 나올까요?", "label": 0 },
#   { "text": "롯테의 장난감! 책, 오힘찬 작가가 쓴 게 맞는데, 이 도서관에 구비되어 있는지 궁금합니다.", "label": 0 },
#   { "text": "나오미 배런 작가의 스즈미야 하루히의 우울 책 소장 여부를 확인하고 싶어서요.", "label": 0 },
#   { "text": "혹시 콜리 황 작가의 어떤 과학의 초전자포 책 관련 정보가 검색되는지 봐주세요.", "label": 0 },
#   { "text": "제가 찾는 아르센 뤼팽의 모험 책이요, 깡토 작가 건데, 도서관 목록에 있는지 검색해주십시오.", "label": 0 },
#   { "text": "공자 작가의 동쪽의 에덴이라는 책을 검색 목록에서 찾아주실 수 있나요?", "label": 0 },
#   { "text": "살육의 천사 책, 저자는 아쿠타미 게게이고요, 이 도서관에 있는지 검색 결과가 궁금합니다.", "label": 0 },
#   { "text": "엔도 슈사쿠 작가가 집필한 아르센 뤼팽의 모험 책이 우리 도서관 소장 도서인지 확인 요청드립니다.", "label": 0 },
#   { "text": "이곳에서 신의 괴도 잔느 책, 김성옥 작가 작품을 검색할 수 있는지 문의합니다.", "label": 0 },
#   { "text": "차란 란가나스 작가의 스즈미야 하루히의 폭주 책이 도서관에 있는지 없는지 검색으로 확인 가능할까요?", "label": 0 },
#   { "text": "나가토 유키짱의 소실 책 관련해서 검색하고 있는데, 조성민 작가 책이 맞는지랑 여기 있는지 알려주세요.", "label": 0 },
#   { "text": "조혜련 작가의 몬테크리스토 백작 책을 도서관 자료에서 검색 가능합니까?", "label": 0 },
#   { "text": "제가 찾는 책은 스즈미야 하루히의 음모 이고 작가는 CLAMP인데, 검색 결과 좀 알려주세요.", "label": 0 },
#   { "text": "혹시 안톤 파블로비치 체호프  작가의 스즈미야 하루히의 분열 책이 도서관 장서 목록에 포함되어 있는지 검색 가능할까요?", "label": 0 },
#   { "text": "마기: 신드바드의 모험 책을 찾고 있습니다. 저자는 R. C. 스프로울인데, 검색 시스템에 있는지 봐주세요.", "label": 0 },
#   { "text": "사와 고지 작가의 책벌레의 하극상 책이 있는지 확인하기 위해 검색을 요청합니다.", "label": 0 },
#   { "text": "이 도서관에서 이철희 작가의 걸리버 여행기 책을 검색하면 결과가 나오는지 궁금해서요.", "label": 0 },
#   { "text": "제로의 사역마 책, 작가 유시민 거, 도서관 검색 목록에 있는지 확인해볼 수 있을까요?", "label": 0 },
#   { "text": "김수정 작가의 재와 환상의 그림갈 책이 여기 있는지 검색해보고 싶어요.", "label": 0 },
#   { "text": "스즈미야 하루히의 경악 책, 저자 최지영의 도서가 이 도서관에 있는지 검색 결과 확인 부탁합니다.", "label": 0 },
#   { "text": "아마미야 우리 작가의 허클베리 핀의 모험 책을 소장하고 있는지 검색 시스템으로 확인해주실 수 있나요?", "label": 0 },
#   { "text": "혹시 코바야시네 메이드래곤 책이 저희 도서관에 있는지 검색해볼 수 있을까요? 작가는 이진우입니다.", "label": 0 },
#   { "text": "비노스 라마찬드라 작가의 식극의 소마 책이 이 도서관에 있는지 검색해주실 수 있나요?", "label": 0 },
#   { "text": "혹시 바람의 검심 책, 김덕진 작가 거, 여기 소장 자료인지 확인 가능할까요?", "label": 0 },
#   { "text": "제가 찾는 책은 모리시타 수 작가의 코이즈미 이츠키의 음모인데, 도서관 검색 시스템에서 찾아볼 수 있을까요?", "label": 0 },
#   { "text": "신만이 아는 세계 이 책, 리사 펠드먼 배럿 작가 작품인데, 저희 도서관에 있는지 검색 부탁드립니다.", "label": 0 },
#   { "text": "서승완 작가가 쓴 장 발장의 이야기 책이 여기 있는지 조회 좀 해주세요.", "label": 0 },
#   { "text": "이 도서관 데이터베이스에서 이철희 작가의 오즈의 마법사 책을 검색해보고 싶습니다.", "label": 0 },
#   { "text": "나만이 없는 거리 책, 저자가 프란츠 카프카인데, 소장 여부 확인 좀 부탁드릴게요.", "label": 0 },
#   { "text": "박성현 작가의 작품 중에 오다 노부나의 야망 이라는 책이 있는지 알아봐 주실 수 있나요?", "label": 0 },
#   { "text": "여기서 하마지 아키 작가의 하늘의 유실물 책을 검색하면 나올까요?", "label": 0 },
#   { "text": "강철의 라인배럴 책, 김일환 작가가 쓴 게 맞는데, 이 도서관에 구비되어 있는지 궁금합니다.", "label": 0 },
#   { "text": "리처드 도킨스 작가의 나의 히어로 아카데미아 책 소장 여부를 확인하고 싶어서요.", "label": 0 },
#   { "text": "혹시 김태유 작가의 쿠로코의 농구 책 관련 정보가 검색되는지 봐주세요.", "label": 0 },
#   { "text": "제가 찾는 우동나라의 황금색 털뭉치 책이요, 피터 틸 작가 건데, 도서관 목록에 있는지 검색해주십시오.", "label": 0 },
#   { "text": "루이스 캐럴 작가의 마왕학원의 부적합자라는 책을 검색 목록에서 찾아주실 수 있나요?", "label": 0 },
#   { "text": "마녀의 여행 책, 저자는 마츠모토 나오야이고요, 이 도서관에 있는지 검색 결과가 궁금합니다.", "label": 0 },
#   { "text": "유시민 작가가 집필한 흑의 계약자 책이 우리 도서관 소장 도서인지 확인 요청드립니다.", "label": 0 },
#   { "text": "이곳에서 어떤 마술의 금서목록 책, 제럴드 오콜린스 작가 작품을 검색할 수 있는지 문의합니다.", "label": 0 },
#   { "text": "박재현 작가의 강철의 라인배럴 책이 도서관에 있는지 없는지 검색으로 확인 가능할까요?", "label": 0 },
#   { "text": "류가죠 나나나의 매장금 책 관련해서 검색하고 있는데, 리사 펠드먼 배럿 작가 책이 맞는지랑 여기 있는지 알려주세요.", "label": 0 },
#   { "text": "네오쇼코 작가의 코드 기어스: 반역의 를르슈 책을 도서관 자료에서 검색 가능합니까?", "label": 0 },
#   { "text": "제가 찾는 책은 아노하나 이고 작가는 하마지 아키인데, 검색 결과 좀 알려주세요.", "label": 0 },
#   { "text": "혹시 제시카 윤 작가의 성계의 문장 책이 도서관 장서 목록에 포함되어 있는지 검색 가능할까요?", "label": 0 },
#   { "text": "소공자 세드릭 책을 찾고 있습니다. 저자는 피터 틸인데, 검색 시스템에 있는지 봐주세요.", "label": 0 },
#   { "text": "코이케 류노스케 작가의 회복술사의 재시작 책이 있는지 확인하기 위해 검색을 요청합니다.", "label": 0 },
#   { "text": "이 도서관에서 아이다이로 작가의 빨강머리 앤 책을 검색하면 결과가 나오는지 궁금해서요.", "label": 0 },
#   { "text": "스즈미야 하루히의 직관 책, 작가 알베르 카뮈 거, 도서관 검색 목록에 있는지 확인해볼 수 있을까요?", "label": 0 },
#   { "text": "장우석 작가의 빨강머리 앤 책이 여기 있는지 검색해보고 싶어요.", "label": 0 },
#   { "text": "시간의 지배자 책, 저자 김덕진의 도서가 이 도서관에 있는지 검색 결과 확인 부탁합니다.", "label": 0 },
#   { "text": "스즈키 유우토 작가의 신만이 아는 세계 책을 소장하고 있는지 검색 시스템으로 확인해주실 수 있나요?", "label": 0 },
#   { "text": "혹시 낙제기사의 영웅담 책이 저희 도서관에 있는지 검색해볼 수 있을까요? 작가는 히다노 켄타로입니다.", "label": 0 },
#   { "text": "도서 검색 좀 하려는데요, 모죠 작가의 변경의 팔라딘 책 있는지 확인해주세요.", "label": 0 },
#   { "text": "언젠가 천마의 검은 토끼 책을 찾는데, 이정모 작가 작품이 여기 도서관에 있나요?", "label": 0 },
#   { "text": "김지훈 작가의 저서 목록 중에 나츠메 우인장 이 책이 우리 도서관 소장품인지 알고 싶습니다.", "label": 0 },
#   { "text": "검색대에서 여고생의 낭비 책, 소라하나 미아 작가 거, 찾아보면 나올까요?", "label": 0 },
#   { "text": "혹시 이 도서관에는 차란 란가나스 작가의 로빈슨 크루소의 모험 책이 없나요? 검색 부탁드립니다.", "label": 0 },
#   { "text": "거울 나라의 앨리스 책이요, 저자가 타치바나 오레코인데, 도서관 소장 목록에서 확인 가능한가요?", "label": 0 },
#   { "text": "김재철 작가가 쓴 롯테의 장난감! 책이 우리 도서관 장서에 포함되는지 조회 가능합니까?", "label": 0 },
#   { "text": "제가 신만이 아는 세계 책을 읽고 싶은데, 지미 송 작가님 책이 여기 있는지 검색 요청합니다.", "label": 0 },
#   { "text": "C. S. 루이스 작가의 치트 약사의 슬로우 라이프 책, 이 도서관 온라인 검색으로도 찾을 수 있나요?", "label": 0 },
#   { "text": "괴병의 라무네 책, 김난도 작가 저서인데, 도서관에 비치되어 있는지 확인해주시면 감사하겠습니다.", "label": 0 }
# ]
