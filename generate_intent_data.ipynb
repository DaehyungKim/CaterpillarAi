# %%
import json
import random
import commentjson


my_label = 1
templatePath = 'intentTemplate/search_book_author_template.jsonc'
entityPath = 'entities/authors.jsonc'


def choose_josa(word, josa_with_batchim, josa_without_batchim):
    if not word:
        return ""
    last_char = word[-1]

    if '가' <= last_char <= '힣':
        has_batchim = (ord(last_char) - ord('가')) % 28 > 0
        return josa_with_batchim if has_batchim else josa_without_batchim

    return josa_without_batchim

def process_korean_template(template, title):
    """템플릿에 제목을 넣고 한국어 조사를 처리하는 함수"""

    text = template.replace('{}', title)

    text = text.replace('{이}', choose_josa(title, '이', ''))
    text = text.replace('{은}', choose_josa(title, '은', '는'))
    text = text.replace('{를}', choose_josa(title, '을', '를'))
    text = text.replace('{과}', choose_josa(title, '과', '와'))
    text = text.replace('{가}', choose_josa(title, '이', '가'))
    text = text.replace('{으로}', choose_josa(title, '으로', '로'))

    return text

def generate_labeled_data(templates, entities, label):
    output_data = []

    for template in templates:

        title = random.choice(entities)

        formatted_text = process_korean_template(template, title)
        data_point = {"text": formatted_text, "label": label}
        output_data.append(data_point)

    return output_data

with open(templatePath, 'r', encoding='utf-8') as f:
    my_templates = commentjson.load(f)
with open(entityPath, 'r', encoding='utf-8') as f:
    my_entities = commentjson.load(f)




generated_data_set1 = generate_labeled_data(my_templates, my_entities, my_label)


item_strings = [json.dumps(item, ensure_ascii=False) for item in generated_data_set1]
output_string = "[\n" + ",\n".join(["  " + "{ " + s[1:-1] + " }" for s in item_strings]) + "\n]"
print(output_string)
# Out:
# [
#   { "text": "도서관에 김범준 작가 책 있어?", "label": 1 },
#   { "text": "손성준 책 있어?", "label": 1 },
#   { "text": "히노하라 메구루 작가 책 있어?", "label": 1 },
#   { "text": "도서관에 말콤 글래드웰 책 있어?", "label": 1 },
#   { "text": "도서관에 캐시 윌리스 작가 책 있어?", "label": 1 },
#   { "text": "혹시 조지 오웰 작가가 쓴 책은 도서관에 있나요?", "label": 1 },
#   { "text": "NAOE 저자의 책 좀 찾아줄래?", "label": 1 },
#   { "text": "앙투안 드 생텍쥐페리라는 사람이 쓴 책을 찾고 싶은데, 도서관에 있을까?", "label": 1 },
#   { "text": "도서관에서 깡토 작품 찾을 수 있을까?", "label": 1 },
#   { "text": "피터 린치 책이 도서관에 있는지 확인해줄래?", "label": 1 },
#   { "text": "김태유 저자의 책 목록 볼 수 있어?", "label": 1 },
#   { "text": "모리시타 수가 쓴 책 중에 도서관에 있는 거 있어?", "label": 1 },
#   { "text": "아오야마 고쇼 작품이 도서관에 있는지 궁금해", "label": 1 },
#   { "text": "이케가야 유지라는 작가 책 좀 보여줄 수 있어?", "label": 1 },
#   { "text": "차란 란가나스 작가가 쓴 책 도서관에 들어왔는지 알아봐줘", "label": 1 },
#   { "text": "모죠 저자 관련 책 보관 중이야?", "label": 1 },
#   { "text": "도서관에 마쓰시타 고노스케 책 재고 있나?", "label": 1 },
#   { "text": "하마지 아키 작가 작품 좀 찾아줄래?", "label": 1 },
#   { "text": "게리 채프먼이 쓴 책 중 최근에 들어온 거 있어?", "label": 1 },
#   { "text": "R. C. 스프로울 저자의 책 소장 중인가요?", "label": 1 },
#   { "text": "헤르만 헤세라는 작가 책 어디에 있는지 알려줘", "label": 1 },
#   { "text": "프란츠 카프카의 책 도서관에서 찾으려면 어디로 가야 해?", "label": 1 },
#   { "text": "도서관에 있는 앙투안 드 생텍쥐페리 작품 목록 볼 수 있어?", "label": 1 },
#   { "text": "룰루 밀러 소설이 도서관에 있는지 궁금해요", "label": 1 },
#   { "text": "이은희 저자 책 검색해줄 수 있어?", "label": 1 },
#   { "text": "도서관에 요즘 인기 많은 작가 중에 박보명의 책도 있을까요?", "label": 1 },
#   { "text": "그 김차차라는 분 책, 혹시 여기서도 볼 수 있나요?", "label": 1 },
#   { "text": "나는 제임스 해밀턴  책을 찾고 있는데, 도서관에 있을지 모르겠네", "label": 1 },
#   { "text": "리사 펠드먼 배럿이 집필한 책이 도서관에 비치되어 있는지요?", "label": 1 },
#   { "text": "도서관 자료 중에 찰스 로버트 다윈이라는 작가 책도 포함돼 있나요?", "label": 1 },
#   { "text": "조혜련 작가의 책을 예전에 읽었는데, 다시 찾아보려고요", "label": 1 },
#   { "text": "요즘 노무라 유스케 저자의 책에 빠졌는데, 여기도 있나요?", "label": 1 },
#   { "text": "혹시 도서관에 지미 송의 대표작이 소장되어 있습니까?", "label": 1 },
#   { "text": "오힘찬이 쓴 책이라면 어떤 게 있는지 알려줄 수 있어?", "label": 1 },
#   { "text": "도서관 서가에서 오오이시 나호 책을 보신 적 있나요?", "label": 1 },
#   { "text": "김태유의 문학 작품을 접하고 싶은데, 뭐가 있을까요?", "label": 1 },
#   { "text": "예전에 박태웅이 쓴 책을 빌렸는데, 아직 있을까?", "label": 1 },
#   { "text": "모리시타 수라는 분 책을 찾고 있는데, 도와주실 수 있나요?", "label": 1 },
#   { "text": "호카조노 타케루 책 말인데요, 도서관에 들어온 적 있나요?", "label": 1 },
#   { "text": "도서관 책 검색할 때 최지영 이름으로도 한번 찾아줄래요?", "label": 1 },
#   { "text": "도서관 자료 중에 칼 세이건이 저술한 책도 있을까요?", "label": 1 },
#   { "text": "이 도서관에서 C. S. 루이스 작품을 본 기억이 나는데요", "label": 1 },
#   { "text": "루이스 캐럴이 쓴 글 중에서 읽어볼 만한 책이 있을까요?", "label": 1 },
#   { "text": "호시노 미즈키라는 이름의 작가 책은 어떻게 검색하죠?", "label": 1 },
#   { "text": "안유석 저자 작품, 도서관에도 소장 중인지요?", "label": 1 },
#   { "text": "도서관에는 제인 오스틴처럼 유명한 작가 책도 많겠죠?", "label": 1 },
#   { "text": "하마지 아키 작가 책 읽어보고 싶은데, 있냐?", "label": 1 },
#   { "text": "도서관 책 검색 시스템에 나오미 배런 입력하면 나올까요?", "label": 1 },
#   { "text": "최근에 원영 작가 책 찾는 사람이 많던데, 도서관에도 있나요?", "label": 1 },
#   { "text": "도서관에 들어온 신간 중에 지미 송 책도 포함되어 있나요?", "label": 1 },
#   { "text": "제가 요즘 관심 있는 작가가 이선 몰릭 인데, 혹시 책이 있나요?", "label": 1 },
#   { "text": "R. C. 스프로울의 수필집을 찾고 싶어요, 도서관에 비치돼 있을까요?", "label": 1 },
#   { "text": "예전에 봤던 진 웹스터 책이 생각나서 다시 찾고 싶은데요", "label": 1 },
#   { "text": "로널드 롤하이저의 저서가 도서관에 있는지 도와줄 수 있을까요?", "label": 1 },
#   { "text": "로버트 기요사키가 쓴 책 중에서 가장 많이 대출된 건 뭘까요?", "label": 1 },
#   { "text": "메리 셸리 작가 책을 찾아봐라", "label": 1 },
#   { "text": "아이다이로가 펴낸 책이 도서관에 입고된 거 있냐?", "label": 1 },
#   { "text": "김일환의 저서가 있는지 궁금해서요", "label": 1 },
#   { "text": "꿈틀이야, 장우석 작가 책이 있는지 확인해 주실 수 있나요?", "label": 1 },
#   { "text": "하마지 아키라는 작가의 이름이 익숙한데, 책 있나요?", "label": 1 },
#   { "text": "캐시 윌리스 책을 친구가 추천해줬는데 도서관에도 있으면 좋겠네요", "label": 1 },
#   { "text": "영끌남 저자의 대표작은 도서관에 비치돼 있습니까?", "label": 1 },
#   { "text": "도서관 자료실에서 캐시 윌리스 관련 도서를 찾을 수 있을까요?", "label": 1 },
#   { "text": "김재철이라는 작가 책은 아직 입고 전인가요?", "label": 1 },
#   { "text": "김직선이 저술한 자료를 찾고 싶은데 도와주세요", "label": 1 },
#   { "text": "박한슬의 문학작품 중 도서관에 있는 책 좀 보여줄 수 있나요?", "label": 1 }
# ]
